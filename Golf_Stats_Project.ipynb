# %% [markdown]
# ### Module 6 - Exploratory Data Project
# ### Trevor Arellanes
# ### Fundamentals of Data Analytics
# ### Domain: Golf

# %% [markdown]
# ### Import needed modules and files for project

# %%
import pandas as pd

golf_data = pd.read_csv('C:\\Users\\tarellanes\\Downloads\\PGATOUR_data2 (2).csv')

# %% [markdown]
# ### Sorting CSV file by points in ascending order

# %%
golf_data = golf_data.sort_values('POINTS', ascending=False)
golf_data
# Out:
#                 Player  EVENTS_PLAYED  POINTS  NUMBER_OF_WINS  \
# 32   Bryson DeChambeau           24.0  5617.0             3.0
# 60      Dustin Johnson           18.0  3289.0             3.0
# 96         Justin Rose           16.0  3191.0             2.0
# 179         Tony Finau           26.0  3169.0             0.0
# 97       Justin Thomas           21.0  3084.0             3.0
# ..                 ...            ...     ...             ...
# 326                NaN            NaN     NaN             NaN
# 327                NaN            NaN     NaN             NaN
# 328                NaN            NaN     NaN             NaN
# 329                NaN            NaN     NaN             NaN
# 330                NaN            NaN     NaN             NaN
#
#      NUMBER_OF_TOP_Tens  POINTS_BEHIND_LEAD  ROUNDS_PLAYED  \
# 32                  9.0                 NaN           85.0
# 60                 11.0              2328.0           69.0
# ...

# %% [markdown]
# ### Displaying the top 25 golfers by points

# %%
sorted_25_golf = golf_data.head(25)
sorted_25_golf
# Out:
#                  Player  EVENTS_PLAYED  POINTS  NUMBER_OF_WINS  \
# 32    Bryson DeChambeau           24.0  5617.0             3.0
# 60       Dustin Johnson           18.0  3289.0             3.0
# 96          Justin Rose           16.0  3191.0             2.0
# 179          Tony Finau           26.0  3169.0             0.0
# 97        Justin Thomas           21.0  3084.0             3.0
# 31        Brooks Koepka           15.0  2551.0             2.0
# 33         Bubba Watson           22.0  2277.0             3.0
# 38        Cameron Smith           22.0  2231.0             0.0
# 138      Phil Mickelson           22.0  1969.0             1.0
# 82            Jason Day           18.0  1935.0             2.0
# 186        Webb Simpson           24.0  1848.0             1.0
# 131     Patrick Cantlay           21.0  1838.0             1.0
# 132        Patrick Reed           24.0  1761.0             1.0
# 64   Francesco Molinari           18.0  1682.0             2.0
# ...

# %% [markdown]
# ### Further sorting data this time by columns of interest using filter function
# ### This is the data that will be analyzed at the end of the module

# %%
sorted_columns = sorted_25_golf.filter(['Player', 'POINTS', 'NUMBER_OF_WINS', 'AVG_driving_DISTANCE', 'UP_AND_DOWN_%', 'MISSED_GIR', 'FAIRWAY_HIT_%', 
                                        'Three_PUTT%', 'AVG_CLUB_HEAD_SPEED', 'AVG_SPIN_RATE', 'AVG_SCORE', 'AGE'])
sorted_columns
# Out:
#                  Player  POINTS  NUMBER_OF_WINS  UP_AND_DOWN_%  MISSED_GIR  \
# 32    Bryson DeChambeau  5617.0             3.0          61.68       441.0
# 60       Dustin Johnson  3289.0             3.0          63.31       338.0
# 96          Justin Rose  3191.0             2.0          63.64       297.0
# 179          Tony Finau  3169.0             0.0          58.01       462.0
# 97        Justin Thomas  3084.0             3.0          63.14       388.0
# 31        Brooks Koepka  2551.0             2.0          64.69       286.0
# 33         Bubba Watson  2277.0             3.0          57.18       383.0
# 38        Cameron Smith  2231.0             0.0          62.47       445.0
# 138      Phil Mickelson  1969.0             1.0          60.85       470.0
# 82            Jason Day  1935.0             2.0          64.46       363.0
# 186        Webb Simpson  1848.0             1.0          66.59       464.0
# ...

# %% [markdown]
# ### Created a histogram to help visualize portions of the data
# ### Used describe method to see general statistics around selected golf statistics

# %%
sorted_columns.hist('AVG_SCORE')
sorted_columns.hist('AGE')
sorted_columns.hist('POINTS')
sorted_columns.describe().round(2)
# Out:
#         POINTS  NUMBER_OF_WINS  UP_AND_DOWN_%  MISSED_GIR  FAIRWAY_HIT_%  \
# count    25.00           25.00          25.00       25.00          25.00
# mean   2095.08            1.28          61.12      390.08          59.99
# std     968.94            1.02           3.32       67.68           4.54
# min    1342.00            0.00          55.36      286.00          52.33
# 25%    1474.00            1.00          58.01      338.00          57.20
# 50%    1761.00            1.00          60.87      388.00          59.06
# 75%    2277.00            2.00          64.26      457.00          63.29
# max    5617.00            3.00          66.59      496.00          71.45
#
#        Three_PUTT%  AVG_CLUB_HEAD_SPEED  AVG_SPIN_RATE  AVG_SCORE    AGE
# count        25.00                25.00          25.00      25.00  25.00
# mean          2.59               116.84        2624.59      69.79  31.00
# std           0.56                 3.16         213.41       0.53   6.32
# ...

# %% [markdown]
# ### Using Correlation method to create matrix of data to be able to draw conclusions from

# %%
final_golf_analysis = sorted_columns.corr().round(3)
final_golf_analysis
# Out:
# C:\Users\tarellanes\AppData\Local\Temp\ipykernel_16856\2524536903.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   final_golf_analysis = sorted_columns.corr().round(3)
#                      POINTS  NUMBER_OF_WINS  UP_AND_DOWN_%  MISSED_GIR  \
# POINTS                1.000           0.571          0.161       0.033
# NUMBER_OF_WINS        0.571           1.000          0.156      -0.204
# UP_AND_DOWN_%         0.161           0.156          1.000      -0.075
# MISSED_GIR            0.033          -0.204         -0.075       1.000
# FAIRWAY_HIT_%        -0.116          -0.103         -0.251      -0.194
# Three_PUTT%           0.062           0.077         -0.437      -0.238
# AVG_CLUB_HEAD_SPEED   0.307           0.284          0.150      -0.406
# ...

# %% [markdown]
# ### Task 5 Bonus  - Using Wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS
import wikipedia
from PIL import Image

stop_w = set(STOPWORDS)
info = wikipedia.summary("Golfing")
word_cloud = WordCloud(stopwords = stop_w).generate(info)
img = word_cloud.to_image()
img.show()
